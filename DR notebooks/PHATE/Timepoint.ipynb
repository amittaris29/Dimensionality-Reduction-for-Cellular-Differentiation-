# %%
import phate
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from  Data_Selection import *

# %%
# Load CSV into a DataFrame
file = 'df_main.csv'
data = pd.read_csv(file)

selected_data, combined_equal_data  = data_selector(7200, file)
datapoint_selection = combined_equal_data[combined_equal_data.iloc[:, 5].isin([2.0, 2.5, 3.0])]
data_to_run = datapoint_selection.drop(datapoint_selection.columns[[5, 6]], axis=1) 
print(selected_data)
print(data_to_run)
# Out:
#            TBX6       BRA      CDX2      SOX2      SOX1
# 0      0.712941  0.245024  1.804050  2.118150  0.748812
# 1      0.396271  0.123065  1.012057  2.676406  0.521711
# 2      0.647942  0.200438  1.300215  5.706961  0.646797
# 3      0.425355  0.157897  0.854942  1.748533  0.441205
# 4      0.381848  0.096692  0.729118  0.508345  0.481436
# ...         ...       ...       ...       ...       ...
# 50395  2.393723  0.187909  0.719677  0.206253  0.811701
# 50396  0.722864  0.448907  1.494106  4.268627  1.728922
# 50397  0.599488  0.364155  2.854191  1.081338  1.334845
# 50398  0.708004  0.285362  0.973050  0.354309  0.953656
# 50399  0.454967  0.262575  0.664267  0.188191  0.667618
#
# [50400 rows x 5 columns]
#            TBX6       BRA      CDX2      SOX2      SOX1
# 0      0.712941  0.245024  1.804050  2.118150  0.748812
# 1      0.396271  0.123065  1.012057  2.676406  0.521711
# 2      0.647942  0.200438  1.300215  5.706961  0.646797
# 3      0.425355  0.157897  0.854942  1.748533  0.441205
# 4      0.381848  0.096692  0.729118  0.508345  0.481436
# ...         ...       ...       ...       ...       ...
# 21595  0.812111  0.764204  1.129056  0.385295  1.301366
# 21596  0.495233  0.187916  1.139577  2.033911  0.578681
# 21597  0.553439  0.221958  1.128493  1.629033  0.811796
# 21598  0.460848  0.162025  1.143683  2.007609  1.319768
# 21599  0.955001  1.879147  4.611071  0.578211  1.295751
#
# [21600 rows x 5 columns]

# %%
phate_op = phate.PHATE()
data_phate = phate_op.fit_transform(selected_data)
# Out:
# Calculating PHATE...
#   Running PHATE on 50400 observations and 5 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 3.48 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.14 seconds.
#   Calculated graph and diffusion operator in 3.65 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 5.93 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 12.28 seconds.
#   Calculated landmark operator in 19.26 seconds.
#   Calculating optimal t...
#     Automatically selected t = 32
#   Calculated optimal t in 26.74 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.78 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 2.85 seconds.
# Calculated PHATE in 53.32 seconds.

# %%
phate_op = phate.PHATE()
data_phate_1 = phate_op.fit_transform(data_to_run)
# Out:
# Calculating PHATE...
#   Running PHATE on 21600 observations and 5 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.89 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.06 seconds.
#   Calculated graph and diffusion operator in 0.96 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 4.78 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 13.97 seconds.
#   Calculated landmark operator in 19.26 seconds.
#   Calculating optimal t...
#     Automatically selected t = 27
#   Calculated optimal t in 48.21 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 1.22 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 2.92 seconds.
# Calculated PHATE in 72.63 seconds.

# %%
plt.figure()
plt.scatter(data_phate[:,0], data_phate[:,1])
plt.show()

# %%
plt.figure()
plt.scatter(data_phate_1[:,0], data_phate_1[:,1])
plt.show()
